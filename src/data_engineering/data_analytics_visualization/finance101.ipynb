# %% [markdown]
# # Python for Finance

# %% [markdown]
# ## 1.ライブラリのインポート

# %%
import datetime as dt

# %% [markdown]
# ## 2.各種設定

# %%
START_DATE = "2025-01-01"
END_DATE = dt.datetime.now(dt.UTC).strftime("%Y-%m-%d")

# %% [markdown]
# ## 3.データ取得

# %% [markdown]
# ### 3-1.Yahoo Finance APIを利用してGAFAMの株価を取得する

# %%
# Out:
# /tmp/ipykernel_6296/4260266423.py:4: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   raw: pd.DataFrame = yf.download(tickers, start=START_DATE, end=END_DATE)
# [*********************100%***********************]  5 of 5 completed

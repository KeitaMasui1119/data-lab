# %%
import polars as pl

# %%
spot_path = r"/workspace/src/stg/data_lake/jepx/spot/spot_summary_2025.parquet"

# %%
df_spot = pl.read_parquet(spot_path)
df_spot.head()
# Out:
# shape: (5, 19)
# ┌───────────┬───────────┬───────────┬───────────┬───┬───────────┬───────────┬───────────┬──────────┐
# │ 受渡日    ┆ 時刻コー  ┆ 売り入札  ┆ 買い入札  ┆ … ┆ 売りブロ  ┆ 売りブロ  ┆ 買いブロ  ┆ 買いブロ │
# │ ---       ┆ ド        ┆ 量(kWh)   ┆ 量(kWh)   ┆   ┆ ック入札  ┆ ック約定  ┆ ック入札  ┆ ック約定 │
# │ str       ┆ ---       ┆ ---       ┆ ---       ┆   ┆ 総量(kWh) ┆ 総量(kWh) ┆ 総量(kWh) ┆ 総量(kWh │
# │           ┆ i64       ┆ i64       ┆ i64       ┆   ┆ ---       ┆ ---       ┆ ---       ┆ )        │
# │           ┆           ┆           ┆           ┆   ┆ i64       ┆ i64       ┆ i64       ┆ ---      │
# │           ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆ i64      │
# ╞═══════════╪═══════════╪═══════════╪═══════════╪═══╪═══════════╪═══════════╪═══════════╪══════════╡
# │ 2025/04/0 ┆ 1         ┆ 15558150  ┆ 15358850  ┆ … ┆ 3297400   ┆ 757450    ┆ 1295500   ┆ 864600   │
# │ 1         ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# ...
